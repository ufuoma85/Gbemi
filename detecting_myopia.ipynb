# %% [markdown]
# <a href="https://colab.research.google.com/github/ufuoma85/Gbemi/blob/main/detecting_myopia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
# Import our input dataset
myopia_df = pd.read_csv('https://static.bc-edx.com/data/dla-1-2/m21/lessons/2/myopia.csv')
myopia_df.head()
# Out:
#    AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0    6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1    6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2    6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3    6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4    5  0.697  23.290001  3.676  3.454  16.16       14       0       0
#
#    STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0        0    10         34      1      1       1
# 1        1     7         12      1      1       0
# 2        0    10         14      0      0       0
# 3        0     4         37      0      1       1
# 4        0     4          4      1      0       0

# %%
# Remove MYOPIC target from features data
y = myopia_df.MYOPIC.values
X = myopia_df.drop(columns="MYOPIC").values
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the deep learning model 
nn_model = tf.keras.models.Sequential()
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu", input_dim=14))
nn_model.add(tf.keras.layers.Dense(units=16, activation="relu"))
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))


# Compile the Sequential model together and customise metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy:{model_accuracy}")
# Out:
# Epoch 1/50
# 15/15 [==============================] - 1s 2ms/step - loss: 0.6705 - accuracy: 0.5853
# Epoch 2/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.5948 - accuracy: 0.7991
# Epoch 3/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.5335 - accuracy: 0.8596
# Epoch 4/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4816 - accuracy: 0.8683
# Epoch 5/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4410 - accuracy: 0.8683
# Epoch 6/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.4082 - accuracy: 0.8683
# Epoch 7/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3852 - accuracy: 0.8683
# Epoch 8/50
# 15/15 [==============================] - 0s 1ms/step - loss: 0.3645 - accuracy: 0.8683
# Epoch 9/50
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3493 - accuracy: 0.8683
# Epoch 10/50
# ...
